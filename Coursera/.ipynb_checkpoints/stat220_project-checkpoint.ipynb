# %%
import requests
import lxml.html as lx
import time
import re
import pandas as pd

# %% [markdown]
# # Udemy Description

# %%
# make a get request on session object and return response
def get_http_response( url, params = {} ):

  time.sleep(0.05)

  try:
    # get request
    response = requests.get( url, params )
    response.raise_for_status()

  # handle exceptions
  except requests.exceptions.HTTPError as e:
    print("Too many requests!!")
    print(e)
    return None

  except requests.exceptions.URLRequired as e:
    print("Invalid URL: Server could not be found for the given url")
    return None

  else:
    # return the response if no exceptions
    return response

# %%
def get_udemy_course_details( url ):
    
    course_description = ''
    learning_objectives = ''
    
    response = get_http_response( url )
    
    try:
        html = lx.fromstring(response.text)
        
        course_description = html.xpath("//body//div[@data-purpose='safely-set-inner-html:description:description']//text()")
        course_description = " ".join(course_description).replace('\xa0', ' ')

        learning_objectives = html.xpath("//body//ul[contains(@class, 'what-you-will-learn--objectives-list-two-column-layout--ED4as')]//div[contains(@class, 'ud-block-list-item-content')]//span/text()")
        learning_objectives = " ".join(learning_objectives)
    except:
        print("No learning onjectives found: " + course_description )
        return course_description if course_description else (learning_objectives if learning_objectives else '')
    else:
        course_details = course_description + ' ' + learning_objectives
        return course_details

# %%
url = 'https://www.udemy.com/course/javascript-web-projects-to-build-your-portfolio-resume'

# %%
desc = get_udemy_course_details(url)

# %%
desc
# Out:
# "Just updated with all modern features of HTML5, CSS3 and JavaScript! Join a live online community of over 900,000+ developers and a course taught by industry experts that have actually worked both in Silicon Valley and Toronto with JavaScript!   This course is focused on efficiency and getting you hired by building your dream portfolio so you can get a job or work as a freelancer. Never spend time on confusing, out of date, incomplete tutorials anymore!  Graduates of Andrei’s courses are now working at Google, Tesla, Amazon, Apple, IBM, JP Morgan, Facebook, + other top tech companies  (seriously, google this to verify some testimonials). Whether you want to become a freelancer, get hired, or to just advance your career,  this brand new course will take you step by step through 20 JavaScript projects that you will be able to customize and put on your portfolio right away.  Along the way, you will learn to build projects using HTML, CSS and JavaScript and truly build your skills as a JavaScript developer. Whether you want to one day learn React, Angular, Vue JS, Node.js, Svelte, or any other toolchain of a modern developer, at the end of the day, JavaScript fundamentals are key, and learning JavaScript is an investment that will pay off many years into the future. By solidifying your JavaScript knowledge and being able to build thing without crutches like libraries and frameworks, you will future proof yourself.  Here is the truth: It’s easy to find JavaScript projects to work on online. You can copy and paste code. You can watch YouTube videos. That’s simple  (and free) . This course is different in that not only de we have modern projects using the latest features of JavaScript, and browser APIs,  but we also do a Code Review of each project.  After we build a website, we go through the code and talk about how we can improve the code, how to improve the security, or improve the performance of your projects. It’s like having a senior developer finally teach you what good code means, what are the common mistakes beginners make, and how to  write maintainable code. All code is going to be provided to you, and even if you don’t like to code along, you will get access to the code for the projects to put them on your portfolio right away. So what are we building? Get ready for this:  Spock Rock Game - Confetti.js, Modules Quote Generator - Fetch, Async/Await, Quote API, CORS Picture-in-Picture - Picture-in-Picture API, Screen Capture API Bookmarks App - DOM, localStorage NASA APOD - Fetch,   Async/Await, NASA API, DOM, localStorage Animated Navigation - CSS Animations Infinite Scroll - Fetch, Async/Await, Unsplash API, DOM, Scroll Event Listener Countdown App - Date, localStorage Music Player - HTML 5 Audio API Calculator - Math Methods Splash Page - DOM Basics Light/Dark Mode - DOM, localStorage Form Validation - DOM, Forms Joke Teller - Fetch, Async/Await, Joke API, Text-to-Speech Video Player - HTML 5 Video API MS Paint Clone - Advanced HTML Canvas, localStorage Pong Clone - Advanced HTML Canvas Math Sprint Game - SetInterval, DOM, Array Methods, localStorage Animated Template - Template, AOS.js Drag and Drop - Drag and Drop API, localStorage We will be using modern ES6,ES7,ES8,ES9,ES10 features to master JavaScript! Think of this as a full on JavaScript bootcamp to get you from a beginner to a confident programmer! on top of that, we also cover common UI/UX practices to make sure we have good designs and our projects are mobile friendly. The course is not about making you just code along without understanding the principles so that when you are done with the course you don’t know what to do other than watch another tutorial. No!  This course will push you and challenge you to go from an absolute beginner in JavaScript to someone that is able to build projects on their own. So the best time to begin? It's Today! By taking that first step right now, you are that much closer to developing the skills that get you hired and closer t ...

# %%
import os

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'initial_udemy_course_title_url_list.csv',
#  'README.md',
#  'stat220_project.ipynb',
#  'Udemy API.ipynb',
#  'udemy_course_all_info_without_description.csv']

# %%
df = pd.read_csv('udemy_course_all_info_without_description.csv')

# %%
df.head()
# Out:
#     course_id                                       course_title  \
# 0  ud_1565838         The Complete 2024 Web Development Bootcamp
# 1   ud_625204                    The Web Developer Bootcamp 2024
# 2   ud_851712  The Complete JavaScript Course 2024: From Zero...
# 3   ud_756150        Angular - The Complete Guide (2024 Edition)
# 4   ud_437398  Build Responsive Real-World Websites with HTML...
#
#                                           course_url  \
# 0  https://www.udemy.com/course/the-complete-web-...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-java...
# 3  https://www.udemy.com/course/the-complete-guid...
# 4  https://www.udemy.com/course/design-and-develo...
#
#           course_instructor  course_rating  course_duration  course_details  \
# 0             Dr. Angela Yu       4.701074             62.0             NaN
# 1               Colt Steele       4.677242             74.0             NaN
# 2         Jonas Schmedtmann       4.713503             68.5             NaN
# 3  Maximilian Schwarzmüller       4.617524             36.5             NaN
# 4         Jonas Schmedtmann       4.757232             37.5             NaN
#
#    course_level  course_no_of_reviews  course_no_of_enrolled
# 0             0                362657                1208632
# 1             0                270209                 902271
# 2             0                201155                 888778
# 3             0                198086                 742648
# 4             0                104332                 412961

# %%
df['course_details'] = df['course_url'].apply(get_udemy_course_details)
# Out:
# Too many requests!!
# 502 Server Error: Bad Gateway for url: https://www.udemy.com/course/understanding-html-and-css/
# No learning onjectives found:
# Too many requests!!
# 502 Server Error: Bad Gateway for url: https://www.udemy.com/course/full-stack-web-development-html-css-bootstrap-and-react-js/
# No learning onjectives found:
# Too many requests!!
# 502 Server Error: Bad Gateway for url: https://www.udemy.com/course/utilize-cpanel-to-maximize-your-websites-potential/
# No learning onjectives found:
# Too many requests!!
# 500 Server Error: Internal Server Error for url: https://www.udemy.com/course/complete-reactjs-developer-bootcamp-build-10-projects/
# No learning onjectives found:

# %%
df.head(10)
# Out:
#     course_id                                       course_title  \
# 0  ud_1565838         The Complete 2024 Web Development Bootcamp
# 1   ud_625204                    The Web Developer Bootcamp 2024
# 2   ud_851712  The Complete JavaScript Course 2024: From Zero...
# 3   ud_756150        Angular - The Complete Guide (2024 Edition)
# 4   ud_437398  Build Responsive Real-World Websites with HTML...
# 5   ud_705264              Modern React with Redux [2024 Update]
# 6   ud_764164              The Complete Web Developer Course 3.0
# 7   ud_995016  Vue - The Complete Guide (incl. Router & Compo...
# 8  ud_1352468  Master Microservices with Spring Boot and Spri...
# 9   ud_822444  Python and Django Full Stack Web Developer Boo...
#
#                                           course_url  \
# 0  https://www.udemy.com/course/the-complete-web-...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-java...
# 3  https://www.udemy.com/course/the-complete-guid...
# 4  https://www.udemy.com/course/design-and-develo...
# 5          https://www.udemy.com/course/react-redux/
# 6  https://www.udemy.com/course/the-complete-web-...
# 7  https://www.udemy.com/course/vuejs-2-the-compl...
# 8  https://www.udemy.com/course/microservices-wit...
# 9  https://www.udemy.com/course/python-and-django...
#
#           course_instructor  course_rating  course_duration  \
# 0             Dr. Angela Yu       4.701074             62.0
# 1               Colt Steele       4.677242             74.0
# 2         Jonas Schmedtmann       4.713503             68.5
# 3  Maximilian Schwarzmüller       4.617524             36.5
# 4         Jonas Schmedtmann       4.757232             37.5
# 5            Stephen Grider       4.729831             43.5
# 6              Rob Percival       4.611889             31.0
# 7  Maximilian Schwarzmüller       4.757785             32.0
# 8      in28Minutes Official       4.570384             25.0
# 9             Jose Portilla       4.456585             32.0
#
#                                       course_details  course_level  \
# 0  Welcome to the Complete Web Development Bootca...             0
# 1  Now with over 10 hours of React content.  Just...             0
# 2  The #1 bestselling JavaScript course on Udemy!...             0
# 3  Join the most comprehensive and bestselling An...             0
# 4  *** The #1 bestselling HTML and CSS course on ...             0
# 5  This course gets updated frequently! Here are ...             0
# 6  25hrs+ BRAND NEW CONTENT to get you coding in ...             0
# 7  Join this bestselling Vue course to learn how ...             0
# 8  Do you want to learn from the  MOST POPULAR  C...             0
# 9  Welcome to the Python and Django Full Stack We...             0
#
#    course_no_of_reviews  course_no_of_enrolled
# 0                362657                1208632
# 1                270209                 902271
# 2                201155                 888778
# 3                198086                 742648
# 4                104332                 412961
# 5                 85893                 314340
# 6                 71955                 313401
# 7                 62231                 235722
# 8                 50167                 248246
# 9                 49455                 207962

# %%
df['course_details'].apply(lambda x: x.strip())
# Out:
# 0       Welcome to the Complete Web Development Bootca...
# 1       Now with over 10 hours of React content.  Just...
# 2       The #1 bestselling JavaScript course on Udemy!...
# 3       Join the most comprehensive and bestselling An...
# 4       *** The #1 bestselling HTML and CSS course on ...
#                               ...
# 5651    Are you fascinated by the art of web developme...
# 5652    Unleash the Power of String Diffing: Build & D...
# 5653    Follow along with the course to create a full ...
# 5654    Gives students and advanced learners a good gr...
# 5655    You can code!  This HTML course is designed fo...
# Name: course_details, Length: 5656, dtype: object

# %%
df = df[df['course_details'] != ' ']

# %%
count = (df['course_details'] == ' ').sum()

# %%
len(df)
# Out:
# 5642

# %%
empty_details_indices = df['course_details'] == ''

# %%
df.loc[empty_details_indices, 'course_details'] = df.loc[empty_details_indices, 'course_url'].apply(get_udemy_course_details)

# %%
print(df[df['course_details'] == ''].index)
# Out:
# Index([], dtype='int64')

# %%
df.to_csv('udemy_course_all_info.csv')

# %% [markdown]
# #  Coursera

# %%
coursera_base_url = 'https://www.coursera.org'

coursera_course_id = 100000

# %%
def generate_course_id():
    
    global coursera_course_id
    new_id = coursera_course_id
    coursera_course_id += 1
    
    return new_id    



def get_course_links( url, params ):
    
    url = url + '/courses'
    res = get_http_response( url, params )
    print(res.request.url)
    try:
        html = lx.fromstring(res.text)

        course_links = html.xpath("//li//a[contains(@class, 'cds-CommonCard-titleLink')]")
        course_links = get_url_and_reviews(course_links)
        
    except Exception as e:
        print("No courses found: ")
        print(e)
        return []
    else:
        return course_links
    
    
    
def get_url_and_reviews( locators ):
    
    all_link_details = []
    
    for locator in locators:
        details = {}
        
        details['url'] = coursera_base_url + locator.get("href")
        
        footer = locator.xpath("ancestor::div[@class='cds-ProductCard-header']/following-sibling::div[@class='cds-ProductCard-footer']/div[@class='cds-CommonCard-ratings']//text()")
        
        details['rating'] = footer
        
        all_link_details.append(details)
        
    return all_link_details

    

def get_all_course_links( url ):
    
    all_course_links = []
    
    params = {
        'query': 'web development',
        'productTypeDescription': 'Courses',
        'page': 1
    }
    
    res = get_http_response( url + '/courses', params )
    
    try:
        html = lx.fromstring(res.text)

        course_links = html.xpath("//li//a[contains(@class, 'cds-CommonCard-titleLink')]")
        course_links = get_url_and_reviews(course_links)
        
        num_pages = int(html.xpath("(//div[contains(@class, 'pagination-controls-container')]//a)[last()-1]/text()")[0])
        
    except Exception as e:
        print(e)
    else:
        all_course_links += course_links
    
    for i in range(2, num_pages+1):
        params['page'] = i
        
        page_course_links = get_course_links(url, params)
        
        all_course_links += page_course_links
        
    return all_course_links

# %%
res = get_http_response( coursera_base_url )

# %%
links = get_course_links(coursera_base_url, params)
# Out:
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=1

# %%
links
# Out:
# [{'url': 'https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#   'rating': ['4.7', '(16K reviews)']},
#  {'url': 'https://www.coursera.org/learn/introduction-to-web-development-with-html-css-javacript',
#   'rating': ['4.6', '(1.9K reviews)']},
#  {'url': 'https://www.coursera.org/learn/web-development',
#   'rating': ['4.7', '(3.6K reviews)']},
#  {'url': 'https://www.coursera.org/learn/introduction-to-front-end-development',
#   'rating': ['4.8', '(10K reviews)']},
#  {'url': 'https://www.coursera.org/learn/python-for-applied-data-science-ai',
#   'rating': ['4.6', '(35K reviews)']},
#  {'url': 'https://www.coursera.org/learn/programming-with-javascript',
#   'rating': ['4.7', '(3.7K reviews)']},
#  {'url': 'https://www.coursera.org/learn/getting-started-with-front-end-and-web-development',
#   'rating': ['4.5', '(88 reviews)']},
#  {'url': 'https://www.coursera.org/learn/developing-frontend-apps-with-react',
#   'rating': ['4.3', '(363 reviews)']},
#  {'url': 'https://www.coursera.org/learn/html-and-css-in-depth',
#   'rating': ['4.7', '(1.4K reviews)']},
#  {'url': 'https://www.coursera.org/learn/web-applications-php',
#   'rating': ['4.7', '(4.2K reviews)']},
#  {'url': 'https://www.coursera.org/learn/developing-backend-apps-with-nodejs-and-express',
#   'rating': ['4.4', '(303 reviews)']},
#  {'url': 'https://www.coursera.org/learn/launch-online-business',
#   'rating': ['4.8', '(531 reviews)']}]

# %%
links = get_all_course_links(coursera_base_url)
# Out:
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=2
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=3
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=4
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=5
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=6
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=7
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=8
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=9
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=10
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=11
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=12
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=13
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=14
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=15
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=16
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=17
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=18
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=19
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=20
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=21
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=22
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=23
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=24
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=25
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=26
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=27
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=28
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=29
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=30
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=31
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=32
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=33
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=34
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=35
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=36
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=37
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=38
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=39
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=40
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=41
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=42
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=43
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=44
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=45
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=46
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=47
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=48
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=49
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=50
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=51
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=52
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=53
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=54
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=55
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=56
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=57
# https://www.coursera.org/courses?query=web+development&productTypeDescription=Courses&page=58

# %%
links[95]
# Out:
# {'url': 'https://www.coursera.org/learn/gen-ai-in-cybersecurity', 'rating': []}

# %%
with open("coursera_links.txt", "w") as file:
    for link in links:
        file.write(link + "\n")

# %%
with open("coursera_links.txt", "r") as file:
    links = file.readlines()

# %%
links = [link.strip() for link in links]

# %%
links
# Out:
# ['https://www.coursera.org/learn/html-css-javascript-for-web-developers',
#  'https://www.coursera.org/learn/introduction-to-web-development-with-html-css-javacript',
#  'https://www.coursera.org/learn/web-development',
#  'https://www.coursera.org/learn/introduction-to-front-end-development',
#  'https://www.coursera.org/learn/python-for-applied-data-science-ai',
#  'https://www.coursera.org/learn/html-and-css-in-depth',
#  'https://www.coursera.org/learn/developing-frontend-apps-with-react',
#  'https://www.coursera.org/learn/developing-backend-apps-with-nodejs-and-express',
#  'https://www.coursera.org/learn/getting-started-with-front-end-and-web-development',
#  'https://www.coursera.org/learn/programming-with-javascript',
#  'https://www.coursera.org/learn/launch-online-business',
#  'https://www.coursera.org/learn/learn-react',
#  'https://www.coursera.org/learn/html',
#  'https://www.coursera.org/learn/web-applications-php',
#  'https://www.coursera.org/learn/javascript-for-web-development',
#  'https://www.coursera.org/learn/introduction-to-back-end-development',
#  'https://www.coursera.org/learn/duke-programming-web',
#  'https://www.coursera.org/learn/single-page-web-apps-with-angularjs',
#  'https://www.coursera.org/learn/learn-javascript',
#  'https://www.coursera.org/learn/front-end-development-capstone-project',
#  'https://www.coursera.org/learn/the-full-stack',
#  'https://www.coursera.org/learn/creative-thinking-techniques-and-tools-for-success',
#  'https://www.coursera.org/learn/learn-html-and-css',
#  'https://www.coursera.org/learn/javascript-basics',
#  'https://www.coursera.org/learn/html--css-crash-course',
#  'https://www.coursera.org/learn/build-a-webpage-with-html-and-css',
#  'https://www.coursera.org/learn/foundations-user-experience-design',
#  'https://www.coursera.org/learn/codio-introduction-to-vuejs-framework',
#  'https://www.coursera.org/learn/internet-history',
#  'https://www.coursera.org/learn/ajax-for-web-developers',
#  'https://www.coursera.org/learn/laravel-framework-and-php',
#  'https://www.coursera.org/learn/node-js',
#  'https://www.coursera.org/learn/python-network-data',
#  'https://www.coursera.org/learn/meta-front-end-developer-capstone',
#  'https://www.coursera.org/learn/web-app',
#  'https://www.coursera.org/learn/understanding-technology-and-data',
#  'https://www.coursera.org/learn/how-to-get-into-web-development',
#  'https://www.coursera.org/learn/react-basics',
#  'https://www.coursera.org/learn/learning-knowledge-human-development',
#  'https://www.coursera.org/learn/intermediate-web-and-front-end-development',
#  'https://www.coursera.org/learn/app-inventor-android',
#  'https://www.coursera.org/learn/introcss',
#  'https://www.coursera.org/learn/javascript-jquery-json',
#  'https://www.coursera.org/learn/database-applications-php',
#  'https://www.coursera.org/learn/learn-typescript',
#  'https://www.coursera.org/learn/intro-to-dotnet-core',
#  'https://www.coursera.org/learn/how-to-create-a-website',
#  'https://www.coursera.org/learn/illinois-tech-fundamentals-of-web-development',
#  'https://www.coursera.org/learn/mafash',
#  'https://www.coursera.org/learn/version-control-with-git',
#  'https://www.coursera.org/learn/website-coding',
#  'https://www.coursera.org/learn/android-app',
#  'https://www.coursera.org/learn/learn-to-code-with-ai',
#  'https://www.coursera.org/learn/python-data-processing',
#  'https://www.coursera.org/learn/neurobiology',
#  'https://www.coursera.org/learn/c-sharp-for-dot-net',
#  'https://www.coursera.org/learn/legal-tech-startups',
#  'https://www.coursera.org/learn/data-structures--backend-with-java',
#  'https://www.coursera.org/learn/javascript-interview-challenges',
#  'https://www.coursera.org/learn/learn-flexbox',
#  'https://www.coursera.org/learn/website-coding-ar',
#  'https://www.coursera.org/learn/secure-full-stack-mean-developer',
#  'https://www.coursera.org/learn/comptia-aplus-cyber',
#  'https://www.coursera.org/learn/web-data',
#  'https://www.coursera.org/learn/satisfaction-guaranteed',
#  'https://www.coursera.org/learn/fundamentals-of-microfrontends',
#  'https://www.coursera.org/learn/learn-css-grid',
#  'https://www.coursera.org/learn/being-a-teacher',
#  'https://www.coursera.org/learn/an-introduction-to-programming-using-python',
#  'https://www.coursera.org/learn/prompt-engineering-for-web-developers',
#  'https://www.coursera.org/learn/advanced-data-engineering',
#  'https://www.coursera.org/learn/backend-development-capstone-project',
#  'https://www.coursera.org/learn/newlearning',
#  'https://www.coursera.org/learn/codio-go-golang-for-python-developers',
#  'https://www.coursera.org/learn/comptia-aplus-network',
#  'https://www.coursera.org/learn/uva-darden-design-thinking-social-sector',
#  'https://www.coursera.org/learn/frontend-development-for-java-full-stack',
#  'https://www.coursera.org/learn/gen-ai-in-cybersecurity',
#  'https://www.coursera.org/learn/illinois-tech-programming-and-application-foundations',
#  'https://www.coursera.org/learn/social-media-data-analytics',
#  'https://www.coursera.org/learn/search-engine-optimization',
#  'https://www.coursera.org/learn/advanced-java',
#  'https://www.coursera.org/learn/cloud-services-java-spring-framework',
#  'https://www.coursera.org/learn/analysis-of-algorithms',
#  'https://www.coursera.org/learn/implant-dentistry',
#  'https://www.coursera.org/learn/transmedia-storytelling',
#  'https://www.coursera.org/learn/uva-darden-market-analytics',
#  'https://www.coursera.org/learn/understanding-political-concepts',
#  'https://www.coursera.org/learn/documentation-usability-cancer-informatics',
#  'https://www.coursera.org/learn/developing-applications-in-python-on-aws',
#  'https://www.coursera.org/learn/visualization-for-data-journalism',
#  'https://www.coursera.org/learn/cobol-programming-vscode',
#  'https://www.coursera.org/learn/ar-games-using-vuforia-sdk',
#  'https://www.coursera.org/learn/arts-heritage',
#  'https://www.coursera.org/learn/aws-well-architected-framework',
#  'https://www.coursera.org/learn/build-a-mobile-app-with-firebase',
#  'https://www.coursera.org/learn/containerized-applications-on-aws',
#  'https://www.coursera.org/learn/getvirtual',
#  'https://www.coursera.org/learn/healing-with-the-arts',
#  'https://www.coursera.org/learn/aws-cloud-consultant-skills',
#  'https://www.coursera.org/learn/capstone-project-using-nodejs',
#  'https://www.coursera.org/learn/gun-violence',
#  'https://www.coursera.org/learn/ai-102-microsoft-azure-ai-engineer-associate-course',
#  'https://www.coursera.org/learn/introduction-to-software-engineering',
#  'https://www.coursera.org/learn/responsive-web-design-adobe-xd',
#  'https://www.coursera.org/learn/python-project-for-data-science',
#  'https://www.coursera.org/learn/programming-in-python',
#  'https://www.coursera.org/learn/application-security-for-developers-devops',
#  'https://www.coursera.org/learn/full-stack-software-developer-assessment',
#  'https://www.coursera.org/learn/javascript',
#  'https://www.coursera.org/learn/principles-of-ux-ui-design',
#  'https://www.coursera.org/learn/java-programming',
#  'https://www.coursera.org/learn/intro-to-mobile-development',
#  'https://www.coursera.org/learn/web-application-development',
#  'https://www.coursera.org/learn/responsive-web-design',
#  'https://www.coursera.org/learn/introduction-to-version-control',
#  'https://www.coursera.org/learn/attract-and-engage-customers',
#  'https://www.coursera.org/learn/project-management',
#  'https://www.coursera.org/learn/hands-on-introduction-to-linux-commands-and-shell-scripting',
#  'https://www.coursera.org/learn/getting-started-with-git-and-github',
#  'https://www.coursera.org/learn/python-project-for-ai-application-development',
#  'https://www.coursera.org/learn/applied-data-science-capstone',
#  'https://www.coursera.org/learn/microsoft-azure-cloud-services',
#  'https://www.coursera.org/learn/visual-elements-user-interface-design',
#  'https://www.coursera.org/learn/python-project-for-data-engineering',
#  'https://www.coursera.org/learn/aspectos-basicos-del-diseno-de-la-experiencia-del-usuario-ux',
#  'https://www.coursera.org/learn/seo-fundamentals',
#  'https://www.coursera.org/learn/advanced-react',
#  'https://www.coursera.org/learn/project-practicum-with-multiple-projects',
#  'https://www.coursera.org/learn/project-planning-1',
#  'https://www.coursera.org/learn/python-databases',
#  'https://www.coursera.org/learn/chronic-pain',
#  'https://www.coursera.org/learn/biomedvis',
#  'https://www.coursera.org/learn/blockchain-basics',
#  'https://www.coursera.org/learn/wharton-retail-marketing-strategy',
#  'https://www.coursera.org/learn/fundamentals-of-red-hat-enterprise-linux-9',
#  'https://www.coursera.org/learn/the-business-of-product-management-one',
#  'https://www.coursera.org/learn/intro-sql',
#  'https://www.coursera.org/learn/coding-interview-preparation',
#  'https://www.coursera.org/learn/recruiting-hiring-onboarding-employees',
#  'https://www.coursera.org/learn/global-health-human-animal-ecosystem',
#  'https://www.coursera.org/learn/ux-design-fundamentals',
#  'https://www.coursera.org/learn/introduction-google-workspace',
#  'https://www.coursera.org/learn/intro-religions-ecology',
#  'https://www.coursera.org/learn/introduction-software-programming-and-databases',
#  'https://www.coursera.org/learn/sales-success',
#  'https://www.coursera.org/learn/hotel-distribution',
#  'https://www.coursera.org/learn/applications-development-microservices-serverless-openshift',
#  'https://www.coursera.org/learn/django-web-framework',
#  'https://www.coursera.org/learn/designing-user-interfaces-and-experiences-uiux',
#  'https://www.coursera.org/learn/developing-applications-with-sql-databases-and-django',
#  'https://www.coursera.org/learn/principios-de-desenvolvimento-agil-de-software',
#  'https://www.coursera.org/learn/optimizing-web-search',
#  'https://www.coursera.org/learn/microsoft-azure-management-security',
#  'https://www.coursera.org/learn/teaching',
#  'https://www.coursera.org/learn/ar',
#  'https://www.coursera.org/learn/process-mining',
#  'https://www.coursera.org/learn/algorithms-graphs-data-structures',
#  'https://www.coursera.org/learn/elearning',
#  'https://www.coursera.org/learn/sport-sponsorship',
#  'https://www.coursera.org/learn/hmgt3860mooc',
#  'https://www.coursera.org/learn/automating-real-world-tasks-python',
#  'https://www.coursera.org/learn/public-health-depression',
#  'https://www.coursera.org/learn/introduction-html-css-javascript',
#  'https://www.coursera.org/learn/introduction-to-android-mobile-application-development',
#  'https://www.coursera.org/learn/smarter-contracts',
#  'https://www.coursera.org/learn/desenvolvimento-agil-com-padroes-de-projeto',
#  'https://www.coursera.org/learn/gestao-equipes-negocios',
#  'https://www.coursera.org/learn/introduccion-desarrollo-web',
#  'https://www.coursera.org/learn/sensors-circuit-interface',
#  'https://www.coursera.org/learn/introtoux-principles-and-processes',
#  'https://www.coursera.org/learn/what-is-the-metaverse',
#  'https://www.coursera.org/learn/intro-to-databases-back-end-development',
#  'https://www.coursera.org/learn/ibm-cloud-native-full-stack-development-capstone',
#  'https://www.coursera.org/learn/build-ai-apps-with-chatgpt-dalle-gpt4',
#  'https://www.coursera.org/learn/oraclecloud-infrastructure-foundations',
#  'https://www.coursera.org/learn/teacher-curriculum',
#  'https://www.coursera.org/learn/introduction-to-ios-mobile-application-development',
#  'https://www.coursera.org/learn/marketing-plan',
#  'https://www.coursera.org/learn/dot-net-full-stack-foundation',
#  'https://www.coursera.org/learn/personal-branding',
#  'https://www.coursera.org/learn/managing-as-a-coach',
#  'https://www.coursera.org/learn/professional-teacher',
#  'https://www.coursera.org/learn/learning-for-a-sustainable-future',
#  'https://www.coursera.org/learn/digital-strategy-business-opportunity',
#  'https://www.coursera.org/learn/healthcare-organizations-health-system',
#  'https://www.coursera.org/learn/data-governance-databricks',
#  'https://www.coursera.org/learn/javascript-programming-essentials',
#  'https://www.coursera.org/learn/machine-learning-capstone',
#  'https://www.coursera.org/learn/devops-aws-code-build-test',
#  'https://www.coursera.org/learn/teaching-plan',
#  'https://www.coursera.org/learn/programacion-python',
#  'https://www.coursera.org/learn/django-database-web-apps',
#  'https://www.coursera.org/learn/introduction-to-devsecops',
#  'https://www.coursera.org/learn/literacy-teaching-learning',
#  'https://www.coursera.org/learn/apis',
#  'https://www.coursera.org/learn/decentralized-apps-on-blockchain',
#  'https://www.coursera.org/learn/java-programming-arrays-lists-data',
#  'https://www.coursera.org/learn/react-native-course',
#  'https://www.coursera.org/learn/need-for-systems-engineering',
#  'https://www.coursera.org/learn/desenvolvimento-agil-com-java-avancado',
#  'https://www.coursera.org/learn/assessment-higher-education',
#  'https://www.coursera.org/learn/uva-darden-agile-analytics',
#  'https://www.coursera.org/learn/frontend-development-using-react',
#  'https://www.coursera.org/learn/nonprofit-organizations',
#  'https://www.coursera.org/learn/backend-development-dot-net-fullstack',
#  'https://www.coursera.org/learn/doping',
#  'https://www.coursera.org/learn/neuromarketing-toolbox',
#  'https://www.coursera.org/learn/cplusplus-crypto-i',
#  'https://www.coursera.org/learn/software-architecture-for-big-data-applications',
#  'https://www.coursera.org/learn/devops-dataops-mlops-duke',
#  'https://www.coursera.org/learn/ubiquitouslearning',
#  'https://www.coursera.org/learn/eportfolio-english',
#  'https://www.coursera.org/learn/cs-fundamentals-3',
#  'https://www.coursera.org/learn/web-mobile-testing',
#  'https://www.coursera.org/learn/foundations-of-ar',
#  'https://www.coursera.org/learn/risk-governance-engage-the-board',
#  'https://www.coursera.org/learn/linux-fundamentals',
#  'https://www.coursera.org/learn/design-patterns',
#  'https://www.coursera.org/learn/internetgiants',
#  'https://www.coursera.org/learn/ejecucion-del-proyecto-ejecutar-el-proyecto',
#  'https://www.coursera.org/learn/the-social-dimensions-of-antimicrobial-resistance',
#  'https://www.coursera.org/learn/gmail',
#  'https://www.coursera.org/learn/real-world-engineering-management-1',
#  'https://www.coursera.org/learn/developing-websites-and-front-ends-with-bootstrap',
#  'https://www.coursera.org/learn/web-design-strategy',
#  'https://www.coursera.org/learn/contact-center-ai-conversational-design-fundamentals',
#  'https://www.coursera.org/learn/web-design-wireframes-prototypes',
#  'https://www.coursera.org/learn/google-cloud-product-fundamentals',
#  'https://www.coursera.org/learn/positioning',
#  'https://www.coursera.org/learn/browser-based-models-tensorflow',
#  'https://www.coursera.org/learn/programming-fundamentals-swift',
#  'https://www.coursera.org/learn/material-informatics',
#  'https://www.coursera.org/learn/getting-started-with-tensor-flow2',
#  'https://www.coursera.org/learn/back-end-developer-capstone',
#  'https://www.coursera.org/learn/integrate-aws-sdk',
#  'https://www.coursera.org/learn/devops-aws-release-deploy',
#  'https://www.coursera.org/learn/generative-ai-elevate-software-development-career',
#  'https://www.coursera.org/learn/meta-programming-fundamentals-kotlin',
#  'https://www.coursera.org/learn/sustainable-regional-principles-planning-and-transportation',
#  'https://www.coursera.org/learn/create-serverless-applications',
#  'https://www.coursera.org/learn/cloud-native-devops-agile-nosql',
#  'https://www.coursera.org/learn/advanced-cybersecurity-concepts-and-capstone-project',
#  'https://www.coursera.org/learn/customer-understanding-and-digital-marketing-channels',
#  'https://www.coursera.org/learn/industrial-iot-markets-security',
#  'https://www.coursera.org/learn/java-for-android',
#  'https://www.coursera.org/learn/ui-automation-and-selectors',
#  'https://www.coursera.org/learn/teaching-online',
#  'https://www.coursera.org/learn/digital-business-models',
#  'https://www.coursera.org/learn/develop-augmented-virtual-mixed-extended-reality-applications-webxr-unity-unreal',
#  'https://www.coursera.org/learn/devops-and-project-management-aws',
#  'https://www.coursera.org/learn/data-engineering-rust',
#  'https://www.coursera.org/learn/aromatherapy-clinical-use-essential-oils',
#  'https://www.coursera.org/learn/climate-change-sustainability-and-global-public-health',
#  'https://www.coursera.org/learn/advanced-programming-in-swift',
#  'https://www.coursera.org/learn/django-build-web-apps',
#  'https://www.coursera.org/learn/conversational-sales',
#  'https://www.coursera.org/learn/java-spring',
#  'https://www.coursera.org/learn/iot-devices-il',
#  'https://www.coursera.org/learn/fintech',
#  'https://www.coursera.org/learn/selenium-webdriver-python',
#  'https://www.coursera.org/learn/teacher-relationships',
#  'https://www.coursera.org/learn/business-process-management-in-healthcare-organizations',
#  'https://www.coursera.org/learn/fashion-retail-transformation',
#  'https://www.coursera.org/learn/engineering-practices-secure-software-quality',
#  'https://www.coursera.org/learn/unity-and-c-basics',
#  'https://www.coursera.org/learn/service-oriented-architecture',
#  'https://www.coursera.org/learn/web-design-project',
#  'https://www.coursera.org/learn/information-visualization-programming-d3js',
#  'https://www.coursera.org/learn/data-visualization-for-genome-biology',
#  'https://www.coursera.org/learn/computational-social-science-methods',
#  'https://www.coursera.org/learn/quality-improvement-in-healthcare-organizations',
#  'https://www.coursera.org/learn/ar-in-marketing-using-meta-spark',
#  'https://www.coursera.org/learn/preparing-cloud-associate-cloud-engineer-exam',
#  'https://www.coursera.org/learn/devops-aws-operate-monitor',
#  'https://www.coursera.org/learn/ux-design-concept-wireframe',
#  'https://www.coursera.org/learn/spring-mvc-rest-controller',
#  'https://www.coursera.org/learn/sales-interview',
#  'https://www.coursera.org/learn/diseno-de-ux-para-el-bien-social-y-preparacion-para-trabajo',
#  'https://www.coursera.org/learn/esg-investing-setting-standards-conducting-analysis',
#  'https://www.coursera.org/learn/python-programming',
#  'https://www.coursera.org/learn/intermediate-back-end-development-with-node-js-mongodb',
#  'https://www.coursera.org/learn/automation-in-aws',
#  'https://www.coursera.org/learn/sensor-manufacturing-process-control',
#  'https://www.coursera.org/learn/multimodal-literacies',
#  'https://www.coursera.org/learn/healthcare-delivery-in-healthcare-organizations',
#  'https://www.coursera.org/learn/learn-advanced-react',
#  'https://www.coursera.org/learn/urban-climate-governance',
#  'https://www.coursera.org/learn/advanced-deployment-scenarios-tensorflow',
#  'https://www.coursera.org/learn/ios-app-development-swift-5',
#  'https://www.coursera.org/learn/android-programming',
#  'https://www.coursera.org/learn/empowering-with-web3js-web3-applications',
#  'https://www.coursera.org/learn/oo-development-using-c-sharp',
#  'https://www.coursera.org/learn/learnerdifferences',
#  'https://www.coursera.org/learn/google-cloud-native-fundamentals',
#  'https://www.coursera.org/learn/learn-svelte',
#  'https://www.coursera.org/learn/contact-center-ai-operations-and-implementation',
#  'https://www.coursera.org/learn/ccai-virtual-agent-development-in-dialogflow-cx-for-software-developers',
#  'https://www.coursera.org/learn/api-security-apigee-gcp',
#  'https://www.coursera.org/learn/kubernetes-deployment',
#  'https://www.coursera.org/learn/backend-development-with-asp-dot-net',
#  'https://www.coursera.org/learn/codio-advanced-django-building-blog',
#  'https://www.coursera.org/learn/identifying-attracting-and-growing-your-digital-audience',
#  'https://www.coursera.org/learn/sales-enablement-tools-productivity',
#  'https://www.coursera.org/learn/iot-communications',
#  'https://www.coursera.org/learn/teaching-popular-music',
#  'https://www.coursera.org/learn/using-ar-foundation-in-unity',
#  'https://www.coursera.org/learn/introduction-to-version-control-es',
#  'https://www.coursera.org/learn/mobile-development-and-javascript',
#  'https://www.coursera.org/learn/customising-models-tensorflow2',
#  'https://www.coursera.org/learn/create-the-user-interface-with-swiftui',
#  'https://www.coursera.org/learn/software-engineering-modeling-software-systems-using-uml',
#  'https://www.coursera.org/learn/capstone-react-app',
#  'https://www.coursera.org/learn/responsivedesign',
#  'https://www.coursera.org/learn/meta-working-with-data',
#  'https://www.coursera.org/learn/resume-writing',
#  'https://www.coursera.org/learn/fundamentals-network-communications',
#  'https://www.coursera.org/learn/getting-started-app-development',
#  'https://www.coursera.org/learn/c-programming-getting-started',
#  'https://www.coursera.org/learn/working-with-data-in-android',
#  'https://www.coursera.org/learn/programming-with-javascript-es',
#  'https://www.coursera.org/learn/swift-programming',
#  'https://www.coursera.org/learn/connect-your-services-with-microsoft-azure-service-bus',
#  'https://www.coursera.org/learn/digital-channel-planning-ecommerce-strategy',
#  'https://www.coursera.org/learn/iot-architecture',
#  'https://www.coursera.org/learn/working-with-data-in-ios',
#  'https://www.coursera.org/learn/database-engineer-capstone',
#  'https://www.coursera.org/learn/frontend-development-using-angular',
#  'https://www.coursera.org/learn/exam-prep-az-120-azure-for-sap-workloads-specialty',
#  'https://www.coursera.org/learn/r-programming-environment',
#  'https://www.coursera.org/learn/create-the-user-interface-android-studio',
#  'https://www.coursera.org/learn/motors-circuits-design',
#  'https://www.coursera.org/learn/digital-manufacturing-design',
#  'https://www.coursera.org/learn/securing-integrating-components-app',
#  'https://www.coursera.org/learn/react-interview-questions',
#  'https://www.coursera.org/learn/sales-force-management',
#  'https://www.coursera.org/learn/fundamentals-of-nestjs',
#  'https://www.coursera.org/learn/learning-assessment',
#  'https://www.coursera.org/learn/gis-1',
#  'https://www.coursera.org/learn/m2m-iot-interface-design-embedded-systems',
#  'https://www.coursera.org/learn/html-and-css-in-depth-es',
#  'https://www.coursera.org/learn/training-others-nursing-informatics',
#  'https://www.coursera.org/learn/react-basics-es',
#  'https://www.coursera.org/learn/mbse',
#  'https://www.coursera.org/learn/ibm-ai-workflow-ai-production',
#  'https://www.coursera.org/learn/projeyi-baslatma-projeye-basariyla-adim-atma',
#  'https://www.coursera.org/learn/ar-for-web-using-javascript',
#  'https://www.coursera.org/learn/restful-apis-with-node-and-express',
#  'https://www.coursera.org/learn/real-world-engineering-management-3',
#  'https://www.coursera.org/learn/real-world-engineering-management-2',
#  'https://www.coursera.org/learn/3d-printing-applications',
#  'https://www.coursera.org/learn/cloud-data-engineering-duke',
#  'https://www.coursera.org/learn/django-features-libraries',
#  'https://www.coursera.org/learn/leadership-and-disruption',
#  'https://www.coursera.org/learn/uva-coding-for-design-managers-1',
#  'https://www.coursera.org/learn/codio-advanced-django-intro-drf',
#  'https://www.coursera.org/learn/professional-communication-skills-sales',
#  'https://www.coursera.org/learn/codio-angular-for-front-end-engineers',
#  'https://www.coursera.org/learn/java-programming-recommender',
#  'https://www.coursera.org/learn/cloud-computing-foundations-duke',
#  'https://www.coursera.org/learn/android-app-capstone',
#  'https://www.coursera.org/learn/web-app-command-line-tools-for-data-engineering-duke',
#  'https://www.coursera.org/learn/react-mvc-app',
#  'https://www.coursera.org/learn/principles-of-ux-ui-design-es',
#  'https://www.coursera.org/learn/advanced-programming-in-kotlin',
#  'https://www.coursera.org/learn/raspberry-pi-interface',
#  'https://www.coursera.org/learn/iot-cloud',
#  'https://www.coursera.org/learn/web3-and-blockchain-leadership-for-transformation',
#  'https://www.coursera.org/learn/autonomous-runway-detection',
#  'https://www.coursera.org/learn/androidapps',
#  'https://www.coursera.org/learn/disenando-paginas-bootstrap4',
#  'https://www.coursera.org/learn/microservices-and-deployment-by-using-aspnet',
#  'https://www.coursera.org/learn/cloud-machine-learning-engineering-mlops-duke',
#  'https://www.coursera.org/learn/manage-resources-azure',
#  'https://www.coursera.org/learn/deploy-a-website-to-azure-with-azure-app-service',
#  'https://www.coursera.org/learn/material-behavior',
#  'https://www.coursera.org/learn/mastering-ansible-automation',
#  'https://www.coursera.org/learn/introduction-to-front-end-development-es',
#  'https://www.coursera.org/learn/dot-net-foundation',
#  'https://www.coursera.org/learn/ios-app-capstone',
#  'https://www.coursera.org/learn/fandom-social-media-authenticity-digital-age',
#  'https://www.coursera.org/learn/soap-web-services-jax-ws',
#  'https://www.coursera.org/learn/strategies-for-converting-and-retaining-customers-online',
#  'https://www.coursera.org/learn/using-zoom-to-connect-with-learners',
#  'https://www.coursera.org/learn/react-fundamentals',
#  'https://www.coursera.org/learn/restful-web-services-jax-rs',
#  'https://www.coursera.org/learn/alibaba-cloud-computing',
#  'https://www.coursera.org/learn/html-front-end-developer-web-services',
#  'https://www.coursera.org/learn/advanced-blockchain-architecture',
#  'https://www.coursera.org/learn/rust-llmops',
#  'https://www.coursera.org/learn/programandoconjava',
#  'https://www.coursera.org/learn/deploy-a-website-with-azure-virtual-machines',
#  'https://www.coursera.org/learn/design-de-uma-experiencia-do-usuario-para-o-bem-social',
#  'https://www.coursera.org/learn/real-time-systems',
#  'https://www.coursera.org/learn/libraries-and-frameworks-for-frontend-development',
#  'https://www.coursera.org/learn/investments-fundamentals',
#  'https://www.coursera.org/learn/demandmanagement',
#  'https://www.coursera.org/learn/django-javascript-json',
#  'https://www.coursera.org/learn/codio-advanced-django-advanced-drf',
#  'https://www.coursera.org/learn/rpa-development-testing',
#  'https://www.coursera.org/learn/sustainable-transportation-networks-and-streetscapes',
#  'https://www.coursera.org/learn/interactivity-javascript-jquery',
#  'https://www.coursera.org/learn/advanced-c-programming-in-net-core',
#  'https://www.coursera.org/learn/web-application-development-with-aspnet-core',
#  'https://www.coursera.org/learn/devops-build-automation-python',
#  'https://www.coursera.org/learn/rpa-deployment-maintenance',
#  'https://www.coursera.org/learn/testing-and-debugging-in-net-core-applications',
#  'https://www.coursera.org/learn/swift-ios-tables-networking',
#  'https://www.coursera.org/learn/building-scalable-applications-with-net-core',
#  'https://www.coursera.org/learn/ui',
#  'https://www.coursera.org/learn/advanced-ios-development',
#  'https://www.coursera.org/learn/concevoirune-experience-utilisateur-pour-le-bien-commun-et-se-preparer-a-lemploi',
#  'https://www.coursera.org/learn/gcp-exploring-preparing-data-bigquery-jp',
#  'https://www.coursera.org/learn/advanced-react-es',
#  'https://www.coursera.org/learn/coding-interview-preparation-es',
#  'https://www.coursera.org/learn/meta-front-end-developer-capstone-es',
#  'https://www.coursera.org/learn/spring-ecosystem-and-core',
#  'https://www.coursera.org/learn/nonprofit-gov-3',
#  'https://www.coursera.org/learn/hacking-patching',
#  'https://www.coursera.org/learn/cloud-virtualization-containers-api-duke',
#  'https://www.coursera.org/learn/intro-android-graphics',
#  'https://www.coursera.org/learn/android-graphics-opengl-es',
#  'https://www.coursera.org/learn/effective-intercultural-communication',
#  'https://www.coursera.org/learn/attract-and-engage-customers-ua',
#  'https://www.coursera.org/learn/androidapps-2',
#  'https://www.coursera.org/learn/engineeringandroidapps',
#  'https://www.coursera.org/learn/teacher-sel-programs',
#  'https://www.coursera.org/learn/introduction-to-building-web-pages-using-html5-and-css3',
#  'https://www.coursera.org/learn/building-interactive-web-pages-using-javascript',
#  'https://www.coursera.org/learn/developing-responsive-web-pages-using-html5-and-css3',
#  'https://www.coursera.org/learn/introduction-ee',
#  'https://www.coursera.org/learn/aws-software-dev',
#  'https://www.coursera.org/learn/server-side-javascript-with-nodejs',
#  'https://www.coursera.org/learn/objective-c',
#  'https://www.coursera.org/learn/akamai-web-apps',
#  'https://www.coursera.org/learn/art-of-job-interview',
#  'https://www.coursera.org/learn/data-products',
#  'https://www.coursera.org/learn/digital-thread-components',
#  'https://www.coursera.org/learn/gmail-es',
#  'https://www.coursera.org/learn/python-visualization',
#  'https://www.coursera.org/learn/spring-repositories',
#  'https://www.coursera.org/learn/building-a-complete-mean-stack-application',
#  'https://www.coursera.org/learn/search-engine',
#  'https://www.coursera.org/learn/tencent-cloud-solutions-architect-professional',
#  'https://www.coursera.org/learn/introduction-to-android-mobile-application-development-es',
#  'https://www.coursera.org/learn/meta-programming-fundamentals-kotlin-es',
#  'https://www.coursera.org/learn/create-the-user-interface-android-studio-es',
#  'https://www.coursera.org/learn/cyber-security-manufacturing',
#  'https://www.coursera.org/learn/developing-cloud-native-applications',
#  'https://www.coursera.org/learn/codio-software-testing-for-developers',
#  'https://www.coursera.org/learn/linux-basics-the-command-line-interface',
#  'https://www.coursera.org/learn/java-class-library',
#  'https://www.coursera.org/learn/javascript-data-manipulation',
#  'https://www.coursera.org/learn/spring-cloud-overview',
#  'https://www.coursera.org/learn/android-architecturemultimedia-framework',
#  'https://www.coursera.org/learn/building-restful-apis-using-nodejs-and-express',
#  'https://www.coursera.org/learn/learn-react-router-6',
#  'https://www.coursera.org/learn/codio-api-development',
#  'https://www.coursera.org/learn/learn-tailwind-css',
#  'https://www.coursera.org/learn/cyber-security-capstone',
#  'https://www.coursera.org/learn/codio-select-topics-python-django',
#  'https://www.coursera.org/learn/big-data-analysis-deep-dive',
#  'https://www.coursera.org/learn/seluk-beluk-jaringan-komputer',
#  'https://www.coursera.org/learn/ios-app-design-development',
#  'https://www.coursera.org/learn/digital-thread-implementation',
#  'https://www.coursera.org/learn/javascript-security-refreshers',
#  'https://www.coursera.org/learn/ethical-frameworks-action',
#  'https://www.coursera.org/learn/enterprise-java-beans-jakarta-persistence-api',
#  'https://www.coursera.org/learn/ethical-data-driven-technology-leader',
#  'https://www.coursera.org/learn/fundamentals-of-data-visualization',
#  'https://www.coursera.org/learn/contexto-negocios-latam',
#  'https://www.coursera.org/learn/building-services-with-asp-net-web-api',
#  'https://www.coursera.org/learn/dwdesign',
#  'https://www.coursera.org/learn/introduccion-programacion-java',
#  'https://www.coursera.org/learn/ciencia-computacao-python-conceitos-2',
#  'https://www.coursera.org/learn/introducao-aplicativos-android',
#  'https://www.coursera.org/learn/responsive-web-design-capstone',
#  'https://www.coursera.org/learn/assessmentforlearning',
#  'https://www.coursera.org/learn/animation-javascript-jquery',
#  'https://www.coursera.org/learn/fundamentos',
#  'https://www.coursera.org/learn/genetics-society',
#  'https://www.coursera.org/learn/data-structures-design-patterns',
#  'https://www.coursera.org/learn/urban-development',
#  'https://www.coursera.org/learn/pressure-force-motion-humidity-sensors',
#  'https://www.coursera.org/learn/amazon-bedrock-getting-started',
#  'https://www.coursera.org/learn/marketing-digital-es',
#  'https://www.coursera.org/learn/escalamiento-exitoso-e-innovacion-en-los-negocios',
#  'https://www.coursera.org/learn/iot-devices',
#  'https://www.coursera.org/learn/fundamentals-of-vuejs',
#  'https://www.coursera.org/learn/fundamentals-of-red-hat-openshift-for-developers',
#  'https://www.coursera.org/learn/red-social',
#  'https://www.coursera.org/learn/from-figma-to-code',
#  'https://www.coursera.org/learn/javascript-deep-dive',
#  'https://www.coursera.org/learn/teaching-learning',
#  'https://www.coursera.org/learn/mobile-marketing-optimization-tactics-and-analytics',
#  'https://www.coursera.org/learn/digital-information-literacy',
#  'https://www.coursera.org/learn/desarrollar-paginas-web-con-angular',
#  'https://www.coursera.org/learn/c-programming-using-linux-tools-and-libraries',
#  'https://www.coursera.org/learn/ios-app-development-basics',
#  'https://www.coursera.org/learn/building-user-interfaces-using-functional-react-components',
#  'https://www.coursera.org/learn/3d-graphics-android-sensors-vr',
#  'https://www.coursera.org/learn/c-bian-cheng',
#  'https://www.coursera.org/learn/projet-programmation-java',
#  'https://www.coursera.org/learn/china-strategy',
#  'https://www.coursera.org/learn/suffering-and-the-human-condition',
#  'https://www.coursera.org/learn/illinois-tech-introduction-to-open-source-operating-systems-mit',
#  'https://www.coursera.org/learn/learn-sql-with-databricks',
#  'https://www.coursera.org/learn/basic-cryptography-and-crypto-api',
#  'https://www.coursera.org/learn/learn-bootstrap',
#  'https://www.coursera.org/learn/codio-advanced-django-external-apis-task-queuing',
#  'https://www.coursera.org/learn/canal-distribucion',
#  'https://www.coursera.org/learn/html-es',
#  'https://www.coursera.org/learn/healthsystems-policy-research',
#  'https://www.coursera.org/learn/continuous-integration',
#  'https://www.coursera.org/learn/python-network-data-es',
#  'https://www.coursera.org/learn/codio-core-java',
#  'https://www.coursera.org/learn/build--deploy-your-portfolio',
#  'https://www.coursera.org/learn/cloud-iot-platform',
#  'https://www.coursera.org/learn/healthcareconsumerism',
#  'https://www.coursera.org/learn/learn-styled-components-in-react',
#  'https://www.coursera.org/learn/nodejs-unleashed-mastering-backend-development',
#  'https://www.coursera.org/learn/content-strategy-project',
#  'https://www.coursera.org/learn/foundations-of-ar-specialization',
#  'https://www.coursera.org/learn/aadcapstone',
#  'https://www.coursera.org/learn/aws-identity-and-access-management',
#  'https://www.coursera.org/learn/sheng-c-biancheng',
#  'https://www.coursera.org/learn/meta-spark-creator-ar-certification',
#  'https://www.coursera.org/learn/introduction-to-front-end-development-ar',
#  'https://www.coursera.org/learn/aplicaciones-web',
#  'https://www.coursera.org/learn/aws-infrastructure-security',
#  'https://www.coursera.org/learn/desarrollo-lado-servidor-nodejs-express-mongodb',
#  'https://www.coursera.org/learn/everyday-leadership-foundation-ar',
#  'https://www.coursera.org/learn/web3-and-blockchain-transformations-in-global-supply-chains',
#  'https://www.coursera.org/learn/illinois-tech-introduction-to-open-source-application-development',
#  'https://www.coursera.org/learn/illinois-tech-open-source-programming-mit',
#  'https://www.coursera.org/learn/meteor-development',
#  'https://www.coursera.org/learn/r-packages',
#  'https://www.coursera.org/learn/desarrollo-de-aplicaciones',
#  'https://www.coursera.org/learn/sql-para-desarrollo-web',
#  'https://www.coursera.org/learn/codio-select-topics-python-packaging',
#  'https://www.coursera.org/learn/step-into-rpa',
#  'https://www.coursera.org/learn/aws-containerization',
#  'https://www.coursera.org/learn/introduction-to-replit-and-ghostwriter',
#  'https://www.coursera.org/learn/google-cloud-devops-fundamentals',
#  'https://www.coursera.org/learn/how-to-get-into-cloud-computing',
#  'https://www.coursera.org/learn/building-interactive-user-interfaces-using-react-library',
#  'https://www.coursera.org/learn/care-the-first-step-in-tech-innovation-for-entrepreneurs',
#  'https://www.coursera.org/learn/scala-capstone',
#  'https://www.coursera.org/learn/nonprofit-gov-2',
#  'https://www.coursera.org/learn/introduction-to-back-end-development-es',
#  'https://www.coursera.org/learn/fundamentals-of-nuxtjs',
#  'https://www.coursera.org/learn/responsive-design-for-swift-arabic',
#  'https://www.coursera.org/learn/writing-java-code-for-applications',
#  'https://www.coursera.org/learn/python-databases-es',
#  'https://www.coursera.org/learn/illinois-tech-introduction-to-open-source-operating-systems-bit',
#  'https://www.coursera.org/learn/nursing-informatics-leaders',
#  'https://www.coursera.org/learn/comp-thinking-javascript-course-1',
#  'https://www.coursera.org/learn/building-high-quality-digital-experiences-using-material-ui',
#  'https://www.coursera.org/learn/html-ru',
#  'https://www.coursera.org/learn/paths-to-a-sustainable-future',
#  'https://www.coursera.org/learn/fundamentals-of-ngrx',
#  'https://www.coursera.org/learn/android-programming-2',
#  'https://www.coursera.org/learn/ios-swift-app-store-in-app-purchase',
#  'https://www.coursera.org/learn/real-world-cloud-pm-3',
#  'https://www.coursera.org/learn/cybersecurite-site-web-securite',
#  'https://www.coursera.org/learn/ajax-basics',
#  'https://www.coursera.org/learn/chef-devops-infrastructure-automation',
#  'https://www.coursera.org/learn/identidad-digital-cmo-tener-visibilidad-acadmica',
#  'https://www.coursera.org/learn/expressjs-essentials-building-modern-web-apis',
#  'https://www.coursera.org/learn/angular-fundamentals-building-responsive-web-apps-with-ase',
#  'https://www.coursera.org/learn/security',
#  'https://www.coursera.org/learn/python-network-data-ru',
#  'https://www.coursera.org/learn/assessing-health-program-delivery',
#  'https://www.coursera.org/learn/amazon-codewhisperer',
#  'https://www.coursera.org/learn/illinois-tech-open-source-programming-bit',
#  'https://www.coursera.org/learn/responsive-website-examples',
#  'https://www.coursera.org/learn/javascript-security-part-3',
#  'https://www.coursera.org/learn/implement-polyglot-persistence-using-sql-and-nosql-databases',
#  'https://www.coursera.org/learn/python-databases-pt',
#  'https://www.coursera.org/learn/ar-in-marketing-using-meta-spark-specialization',
#  'https://www.coursera.org/learn/learn-responsive-web-design',
#  'https://www.coursera.org/learn/learn-imba',
#  'https://www.coursera.org/learn/principles-of-ux-ui-design-ar',
#  'https://www.coursera.org/learn/introduction-to-ios-mobile-application-development-es',
#  'https://www.coursera.org/learn/introduction-to-es6',
#  'https://www.coursera.org/learn/learn-accessible-web-design',
#  'https://www.coursera.org/learn/aplicaciones-android',
#  'https://www.coursera.org/learn/aplicaciones-mobile-multiplataforma-nativescript-angular-redux',
#  'https://www.coursera.org/learn/developpement-urbain',
#  'https://www.coursera.org/learn/apis-es',
#  'https://www.coursera.org/learn/alibaba-cloud-security-solutions',
#  'https://www.coursera.org/learn/introduction-to-back-end-development-ar',
#  'https://www.coursera.org/learn/build-app',
#  'https://www.coursera.org/learn/health-informatics-leadership',
#  'https://www.coursera.org/learn/codio-restful-mvc-architecture',
#  'https://www.coursera.org/learn/learn-css-animations',
#  'https://www.coursera.org/learn/cloud-app',
#  'https://www.coursera.org/learn/meta-spark-creator-ar-specialization',
#  'https://www.coursera.org/learn/async-javascript',
#  'https://www.coursera.org/learn/iosswift',
#  'https://www.coursera.org/learn/intro-to-databases-back-end-development-es',
#  'https://www.coursera.org/learn/introduction-to-android-mobile-application-development-ar',
#  'https://www.coursera.org/learn/build-reusable-react',
#  'https://www.coursera.org/learn/strategies-senior-housing-covid19',
#  'https://www.coursera.org/learn/programming-with-javascript-ar',
#  'https://www.coursera.org/learn/react-native-course-es',
#  'https://www.coursera.org/learn/learn-class-components-in-react',
#  'https://www.coursera.org/learn/learn-markdown',
#  'https://www.coursera.org/learn/zika',
#  'https://www.coursera.org/learn/data-scientists-tools-ar',
#  'https://www.coursera.org/learn/java-programming-ar',
#  'https://www.coursera.org/learn/react-basics-ar',
#  'https://www.coursera.org/learn/programming-fundamentals-swift-es',
#  'https://www.coursera.org/learn/apis-in-swift-arabic',
#  'https://www.coursera.org/learn/react-js-challenges',
#  'https://www.coursera.org/learn/building-navigational-workflows-using-react',
#  'https://www.coursera.org/learn/django-web-framework-es',
#  'https://www.coursera.org/learn/html-and-css-in-depth-ar',
#  'https://www.coursera.org/learn/the-full-stack-ar',
#  'https://www.coursera.org/learn/mobile-development-and-javascript-es',
#  'https://www.coursera.org/learn/fundamentals-of-flux',
#  'https://www.coursera.org/learn/transreality-gaming',
#  'https://www.coursera.org/learn/alibabacloudbigdata',
#  'https://www.coursera.org/learn/alibaba-developer',
#  'https://www.coursera.org/learn/advanced-react-ar',
#  'https://www.coursera.org/learn/react-native-course-ar',
#  'https://www.coursera.org/learn/introduction-to-ios-mobile-application-development-ar',
#  'https://www.coursera.org/learn/intro-to-databases-back-end-development-ar',
#  'https://www.coursera.org/learn/react-capstone-project',
#  'https://www.coursera.org/learn/introduction-to-version-control-ar',
#  'https://www.coursera.org/learn/building-no-code-apps-using-amazon-honeycode',
#  'https://www.coursera.org/learn/engaging-in-service-innovation-and-management',
#  'https://www.coursera.org/learn/coding-interview-preparation-ar',
#  'https://www.coursera.org/learn/programming-fundamentals-swift-ar',
#  'https://www.coursera.org/learn/advanced-programming-in-swift-es',
#  'https://www.coursera.org/learn/responsivedesign-ar',
#  'https://www.coursera.org/learn/back-end-developer-capstone-es',
#  'https://www.coursera.org/learn/foundations-google-kubernetes-engine-gke-ko',
#  'https://www.coursera.org/learn/advanced-programming-in-kotlin-es',
#  'https://www.coursera.org/learn/meta-programming-fundamentals-kotlin-ar',
#  'https://www.coursera.org/learn/create-the-user-interface-with-swiftui-es',
#  'https://www.coursera.org/learn/cohere---an-introduction',
#  'https://www.coursera.org/learn/debugging-in-swift',
#  'https://www.coursera.org/learn/comp-thinking-javascript-course-2',
#  'https://www.coursera.org/learn/the-full-stack-es',
#  'https://www.coursera.org/learn/mobile-development-and-javascript-ar',
#  'https://www.coursera.org/learn/create-the-user-interface-android-studio-ar',
#  'https://www.coursera.org/learn/tasmim-wajhet-elmostkhdem-fi-apple-xcode-tasmem-wagha',
#  'https://www.coursera.org/learn/icp',
#  'https://www.coursera.org/learn/comp-thinking-javascript-course-3',
#  'https://www.coursera.org/learn/meta-front-end-developer-capstone-ar',
#  'https://www.coursera.org/learn/django-web-framework-ar',
#  'https://www.coursera.org/learn/apis-ar',
#  'https://www.coursera.org/learn/gcp-cost-optimization-jp',
#  'https://www.coursera.org/learn/back-end-developer-capstone-ar',
#  'https://www.coursera.org/learn/working-with-data-in-android-es',
#  'https://www.coursera.org/learn/android-app-capstone-es',
#  'https://www.coursera.org/learn/create-the-user-interface-with-swiftui-ar',
#  'https://www.coursera.org/learn/working-with-data-in-ios-es',
#  'https://www.coursera.org/learn/advanced-programming-in-swift-ar',
#  'https://www.coursera.org/learn/advanced-programming-in-kotlin-ar',
#  'https://www.coursera.org/learn/ui-design-in-xcode',
#  'https://www.coursera.org/learn/nashr-tatbiq-web-biastikhdam-docker-w-kubernetes',
#  'https://www.coursera.org/learn/game-development-unity-ball-launcher',
#  'https://www.coursera.org/learn/augmented-reality',
#  'https://www.coursera.org/learn/advanced-android-development',
#  'https://www.coursera.org/learn/meta-software-development-practices',
#  'https://www.coursera.org/learn/cloud-infrastructure-design-process-br',
#  'https://www.coursera.org/learn/mobile-architecture',
#  'https://www.coursera.org/learn/web-databases',
#  'https://www.coursera.org/learn/ios-mobile-lifecycle-and-software-development-approaches',
#  'https://www.coursera.org/learn/android-mobile-lifecycle-and-software-development-approaches',
#  'https://www.coursera.org/learn/the-web-and-databases-ios',
#  'https://www.coursera.org/learn/essential-cloud-infrastructure-core-services-zhtw',
#  'https://www.coursera.org/learn/working-with-data-in-android-ar',
#  'https://www.coursera.org/learn/ios-app-capstone-es',
#  'https://www.coursera.org/learn/deploying-secure-kubernetes-containers-in-production-ko',
#  'https://www.coursera.org/learn/ios-app-capstone-ar',
#  'https://www.coursera.org/learn/working-with-data-in-ios-ar',
#  'https://www.coursera.org/learn/android-app-capstone-ar',
#  'https://www.coursera.org/learn/unity-kaifa-jinjie',
#  'https://www.coursera.org/learn/html-ar',
#  'https://www.coursera.org/learn/javascript-ar',
#  'https://www.coursera.org/learn/construyendo-android-proyecto',
#  'https://www.coursera.org/learn/introcss-ar',
#  'https://www.coursera.org/learn/dot-net-kaifa-jishu']

# %%
def get_coursera_course_info( course ):
    
    res = get_http_response( course['url'] )
    
    details = {}

    html = lx.fromstring(res.text)

    course_title = html.xpath("//h1/text()")[0]
    details['course_title'] = course_title

    details['course_id'] = 'ce_' + str(generate_course_id())

    details['course_url'] = course['url']

    try:
        instructor = html.xpath("//div/a[starts-with(@href, '/instructor')]/span/text()")[0]
    except Exception as e:
        print(course['url'] + ': --> ')
        print(e)
        details['course_instructor'] = ''
    else:
        details['course_instructor'] = instructor

    if len(course['rating']) > 0:
        details['course_rating'] = float(course['rating'][0])
        
        num_reviews = course['rating'][1].split()[0][1:]
        
        idx = num_reviews.find('K')
        
        multiplier = 1
        
        if idx >= 0:
            num_reviews = num_reviews[0:idx]
            multiplier = 1000
        
        details['course_no_of_reviews'] = int(multiplier * float(num_reviews))
    else:
        details['course_rating'] = None
        details['course_no_of_reviews'] = None

    duration_div_texts = html.xpath("//section//div[@class = 'cds-119 cds-Typography-base css-h1jogs cds-121']/text()")
    duration_str = 0
    for text in duration_div_texts:
        if 'hours' in text.lower():
            matches = re.findall("\d+(?= hours)", text)
            if len(matches) > 0:
                duration_str = matches[0]
            break

    details['course_duration'] = float(duration_str)

    course_level = 0
    for text in duration_div_texts:
        if 'level' in text.lower():
            match = re.findall("\w+(?= level)", text)
    
            if len(match) > 0:
                match = match[0].lower()

                if match == 'beginner':
                    course_level = 1
                elif match == 'intermediate':
                    course_level = 2
                elif match == 'advanced':
                    course_level = 3
                    break

   

    details['course_level'] = course_level


    

    num_enrolled = html.xpath("//div/p/span/strong/span/text()")
    
    if len(num_enrolled) > 0:
        try:
            num_enrolled = int(num_enrolled[0].replace(',', ''))
        except ValueError as e:
            print(course['url'] + ': --> ')
            print(e)
            details['course_no_of_enrolled'] = 0
        else:
            details['course_no_of_enrolled'] = num_enrolled
    else:
        details['course_no_of_enrolled'] = 0

    desc_loc = html.xpath("//div[@id='about']")
    desc = []
    if len(desc_loc) > 0:
        desc_loc = desc_loc[0]
        desc = desc_loc.xpath("descendant::div//ul//p//text()|descendant::div//ul//a/text()")
    
    desc += html.xpath("//div[@id='modules']//span/h3/text()")
    
    details['course_details'] = " ".join(desc).replace('\xa0', ' ')
    
    return details

# %%
res = get_coursera_course_info(links[91])

# %%
all_course_data = [ get_coursera_course_info(course) for course in links ]
# Out:
# https://www.coursera.org/learn/software-architecture-for-big-data-applications: -->
# invalid literal for int() with base 10: ' You may not earn credit for more than one version of a cross-listed course.'
# https://www.coursera.org/learn/data-governance-databricks: -->
# invalid literal for int() with base 10: ' '
# https://www.coursera.org/learn/programming-with-javascript-es: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/introduction-to-version-control-es: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/introduction-to-back-end-development-es: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/html-and-css-in-depth-es: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/react-basics-es: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/meta-programming-fundamentals-kotlin-es: -->
# invalid literal for int() with base 10: 'Ninguna. No se necesita experiencia previa en desarrollo web. Solo conocimientos bÃ¡sicos de navegaciÃ³n por Internet y ganas de empezar a programar.'
# https://www.coursera.org/learn/advanced-react-es: -->
# invalid literal for int() with base 10: 'You will need foundational knowledge of the basics of React HTML CSS and JavaScript and an eagerness to code.'
# https://www.coursera.org/learn/introduction-to-front-end-development-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/introduction-to-back-end-development-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/meta-front-end-developer-capstone-es: -->
# invalid literal for int() with base 10: 'Learners need prior Front-end developer experience to complete this course.'
# https://www.coursera.org/learn/apis-es: -->
# invalid literal for int() with base 10: 'Learners need prior Django development experience to do this course'
# https://www.coursera.org/learn/react-native-course-es: -->
# invalid literal for int() with base 10: 'Learners need foundational knowledge of React basics internet navigation skills and an eagerness to code.'
# https://www.coursera.org/learn/html-and-css-in-depth-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/the-full-stack-ar: -->
# invalid literal for int() with base 10: 'Learners need previous experience with: back-end development Python version control databases Django web framework and APIs.'
# https://www.coursera.org/learn/programming-with-javascript-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/react-basics-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/react-native-course-ar: -->
# invalid literal for int() with base 10: 'Learners need foundational knowledge of React basics internet navigation skills and an eagerness to code.'
# https://www.coursera.org/learn/mobile-development-and-javascript-es: -->
# invalid literal for int() with base 10: 'Ninguno. Los estudiantes no necesitan experiencia previa de desarrollo web. Solo habilidades bÃ¡sicas de navegaciÃ³n y ganas de comenzar a codificar.'
# https://www.coursera.org/learn/programming-fundamentals-swift-es: -->
# invalid literal for int() with base 10: 'Ninguno. Los alumnos no necesitan experiencia en el desarrollo de Swift. Solo conocimientos bÃ¡sicos de navegaciÃ³n por Internet y ganas de programar.'
# https://www.coursera.org/learn/back-end-developer-capstone-es: -->
# invalid literal for int() with base 10: 'Learners need prior Back-end developer experience to complete this course.'
# https://www.coursera.org/learn/advanced-react-ar: -->
# invalid literal for int() with base 10: 'You will need foundational knowledge of the basics of React HTML CSS and JavaScript and an eagerness to code.'
# https://www.coursera.org/learn/programming-fundamentals-swift-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/introduction-to-version-control-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/the-full-stack-es: -->
# invalid literal for int() with base 10: 'Learners need previous experience with: back-end development Python version control databases Django web framework and APIs.'
# https://www.coursera.org/learn/meta-programming-fundamentals-kotlin-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/working-with-data-in-android-es: -->
# invalid literal for int() with base 10: 'To complete this course you should have an advanced understanding of Kotlin programming and a functional knowledge of operating Android Studio.'
# https://www.coursera.org/learn/android-app-capstone-es: -->
# invalid literal for int() with base 10: 'Para completar este curso necesita la experiencia en desarrollo de aplicaciones Android que adquiriÃ³ en los cursos anteriores del programa.'
# https://www.coursera.org/learn/mobile-development-and-javascript-ar: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/advanced-android-development: -->
# list index out of range
# https://www.coursera.org/learn/advanced-ios-development: -->
# list index out of range
# https://www.coursera.org/learn/meta-software-development-practices: -->
# list index out of range
# https://www.coursera.org/learn/mobile-architecture: -->
# list index out of range
# https://www.coursera.org/learn/web-databases: -->
# list index out of range
# https://www.coursera.org/learn/web-databases: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/ios-mobile-lifecycle-and-software-development-approaches: -->
# list index out of range
# https://www.coursera.org/learn/android-mobile-lifecycle-and-software-development-approaches: -->
# list index out of range
# https://www.coursera.org/learn/android-mobile-lifecycle-and-software-development-approaches: -->
# invalid literal for int() with base 10: 'None!'
# https://www.coursera.org/learn/the-web-and-databases-ios: -->
# list index out of range
# https://www.coursera.org/learn/meta-front-end-developer-capstone-ar: -->
# invalid literal for int() with base 10: 'Learners need prior Front-end developer experience to complete this course.'
# https://www.coursera.org/learn/apis-ar: -->
# invalid literal for int() with base 10: 'Learners need prior Django development experience to do this course'
# https://www.coursera.org/learn/back-end-developer-capstone-ar: -->
# invalid literal for int() with base 10: 'Learners need prior Back-end developer experience to complete this course.'
# https://www.coursera.org/learn/working-with-data-in-android-ar: -->
# invalid literal for int() with base 10: 'To complete this course you should have an advanced understanding of Kotlin programming and a functional knowledge of operating Android Studio.'
# https://www.coursera.org/learn/android-app-capstone-ar: -->
# invalid literal for int() with base 10: 'To complete this course you need the  Android app development experience that the previous courses in the program provided you with.  '

# %%
coursera_df = pd.DataFrame(all_course_data)

# %%
coursera_df.head()
# Out:
#                                         course_title  course_id  \
# 0       HTML, CSS, and Javascript for Web Developers  ce_101040
# 1  Introduction to Web Development with HTML, CSS...  ce_101041
# 2                    Introduction to Web Development  ce_101042
# 3              Introduction to Front-End Development  ce_101043
# 4          Python for Data Science, AI & Development  ce_101044
#
#                                           course_url     course_instructor  \
# 0  https://www.coursera.org/learn/html-css-javasc...        Yaakov Chaikin
# 1  https://www.coursera.org/learn/introduction-to...          Upkar Lidder
# 2     https://www.coursera.org/learn/web-development          William Mead
# 3  https://www.coursera.org/learn/introduction-to...  Taught by Meta Staff
# 4  https://www.coursera.org/learn/python-for-appl...  Joseph Santarcangelo
#
#    course_rating  course_no_of_reviews  course_duration  course_level  \
# 0            4.7               16000.0             40.0             0
# 1            4.6                1900.0             12.0             1
# 2            4.7                3600.0             10.0             1
# 3            4.8               10000.0             18.0             1
# 4            4.6               35000.0             26.0             1
#
#    course_no_of_enrolled                                     course_details
# 0                1088947  HTML JavaScript Css Frameworks Cascading Style...
# 1                 133525  Describe the Web Application Development Ecosy...
# 2                 235762  Css Code HTML Web Development Cascading Style ...
# 3                 302618  Distinguish between front-end, back-end, and f...
# 4                 776135  Learn Python - the most popular programming la...

# %%
coursera_df.to_csv('coursera_course_all_info')
